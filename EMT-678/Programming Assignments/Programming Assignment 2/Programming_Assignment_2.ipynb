# %%
from pyspark.sql.functions import monotonically_increasing_id, col, struct, expr, array
from itertools import product

# %% [markdown]
# # Programming Assignment 2
#
# Wyatt Blair
#
# 12/2/2024
#
# Using the environmental data for each of the provinces in Canada, and weighting each piece of data by the number of cities in the province, calculate the mean temperature and mean precipitation for all of Canada for annual and each month.

# %% [markdown]
# ## Load the data

# %%
# %sql
use catalog `hive_metastore`; select * from `default`.`class_9___12____data_for_programming___environmental___vshort_3_csv` limit 100;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th><th>_c6</th><th>_c7</th><th>_c8</th><th>_c9</th><th>_c10</th><th>_c11</th><th>_c12</th><th>_c13</th><th>_c14</th><th>_c15</th><th>_c16</th></tr></thead><tbody><tr><td>Alberta</td><td>ANNUAL </td><td>JAN </td><td>FEB </td><td>MAR </td><td>APR </td><td>MAY </td><td>JUN </td><td>JUL </td><td>AUG </td><td>SEP </td><td>OCT </td><td>NOV </td><td>DEC </td><td>YEARS </td><td># CITIES </td><td>null</td></tr><tr><td>Average Temperature (F)</td><td>36.8</td><td>10.6</td><td>15.8</td><td>25.3</td><td>39.1</td><td>49.5</td><td>56.7</td><td>60.9</td><td>59.2</td><td>50</td><td>39.2</td><td>23.3</td><td>13.8</td><td>24</td><td>245</td><td>null</td></tr><tr><td>Average High Temperature (F)</td><td>48.3</td><td>21.2</td><td>27</td><td>36.2</td><td>51.2</td><td>62.1</td><td>68.8</td><td>73.6</td><td>72.3</td><td>62.5</td><td>50.6</td><td>32.6</td><td>23.8</td><td>25</td><td>236</td><td>null</td></tr><tr><td>Average Low Temperature (F)</td><td>25.8</td><td>0.9</td><td>5</td><td>14.5</td><td>27.4</td><td>36.9</td><td>44.7</td><td>48.5</td><td>46.4</td><td>37.7</td><td>28.2</td><td>14.1</td><td>4.4</td><td>25</td><td>236</td><td>null</td></tr><tr><td>Average Precipitation (in)</td><td>18.2</td><td>0.9</td><td>0.7</td><td>0.9</td><td>1.1</td><td>2</td><td>3.2</td><td>3</td><td>2.3</td><td>1.7</td><td>0.9</td><td>0.9</td><td>0.8</td><td>24</td><td>277</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>British Columbia</td><td>ANNUAL </td><td>JAN </td><td>FEB </td><td>MAR </td><td>APR </td><td>MAY </td><td>JUN </td><td>JUL </td><td>AUG </td><td>SEP </td><td>OCT </td><td>NOV </td><td>DEC </td><td>YEARS </td><td># CITIES </td><td>null</td></tr><tr><td>Average Temperature (F)</td><td>43.7</td><td>27.2</td><td>30.5</td><td>36.7</td><td>43.8</td><td>50.9</td><td>56.8</td><td>61.2</td><td>60.8</td><td>54</td><td>44.3</td><td>34</td><td>27.5</td><td>24</td><td>471</td><td>null</td></tr><tr><td>Average High Temperature (F)</td><td>52.2</td><td>32.9</td><td>37.6</td><td>45.1</td><td>53.5</td><td>61.3</td><td>67.1</td><td>72.2</td><td>72</td><td>64.3</td><td>52</td><td>39.4</td><td>32.8</td><td>24</td><td>469</td><td>null</td></tr><tr><td>Average Low Temperature (F)</td><td>35.2</td><td>21.5</td><td>23.4</td><td>28.2</td><td>34.1</td><td>40.6</td><td>46.5</td><td>50.1</td><td>49.5</td><td>43.7</td><td>36.7</td><td>28.5</td><td>22.3</td><td>24</td><td>469</td><td>null</td></tr><tr><td>Average Precipitation (in)</td><td>49</td><td>7.1</td><td>4.3</td><td>4</td><td>3.3</td><td>2.8</td><td>2.8</td><td>2.2</td><td>2.2</td><td>2.9</td><td>5.3</td><td>6.9</td><td>6.2</td><td>25</td><td>517</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr><tr><td>Manitoba</td><td>ANNUAL </td><td>JAN </td><td>FEB </td><td>MAR </td><td>APR </td><td>MAY </td><td>JUN </td><td>JUL </td><td>AUG </td><td>SEP </td><td>OCT </td><td>NOV </td><td>DEC </td><td>YEARS </td><td># CITIES </td><td>null</td></tr><tr><td>Average Temperature (F)</td><td>34.6</td><td>-0.3</td><td>5.9</td><td>18.5</td><td>36.2</td><td>49.7</td><td>59.6</td><td>64.7</td><td>62.9</td><td>52.1</td><td>39.1</td><td>20.7</td><td>5.6</td><td>25</td><td>144</td><td>null</td></tr><tr><td>Average High Temperature (F)</td><td>44.6</td><td>9.2</td><td>15.9</td><td>28.5</td><td>47.1</td><td>61.6</td><td>70.7</td><td>75.8</td><td>74.4</td><td>62.6</td><td>48.1</td><td>28.3</td><td>14.1</td><td>23</td><td>140</td><td>null</td></tr><tr><td>Average Lo ...

# %%
raw_data = _sqldf.withColumn('row_index', monotonically_increasing_id())

# %% [markdown]
# ## Clean up data

# %%
provinces = raw_data.filter(col('row_index') % 6 == 0).drop('row_index').select('_c0').withColumnRenamed('_c0', 'Province')
n_provinces = provinces.count()

display(provinces)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Province</th></tr></thead><tbody><tr><td>Alberta</td></tr><tr><td>British Columbia</td></tr><tr><td>Manitoba</td></tr><tr><td>New Brunswick</td></tr><tr><td>Newfoundland</td></tr><tr><td>Northwest Territories</td></tr><tr><td>Nova Scotia</td></tr><tr><td>Nunavut</td></tr><tr><td>Ontario</td></tr><tr><td>Prince Edward Island</td></tr><tr><td>Quebec</td></tr><tr><td>Saskatchewan</td></tr><tr><td>Yukon</td></tr></tbody></table></div>

# %%
headers = raw_data.collect()[0][1:-2]
headers = [header.strip().replace('# ', 'N_') for header in headers]
print(headers)
# Out:
# ['ANNUAL', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'YEARS', 'N_CITIES']

# %%
measurements = raw_data.filter(
  (col('row_index') > 0)
  &
  (col('row_index') < 5)
  ).select('_c0').withColumnRenamed('_c0', 'Measurement')
display(measurements)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Measurement</th></tr></thead><tbody><tr><td>Average Temperature (F)</td></tr><tr><td>Average High Temperature (F)</td></tr><tr><td>Average Low Temperature (F)</td></tr><tr><td>Average Precipitation (in)</td></tr></tbody></table></div>

# %%
data = raw_data.filter(
  (col('row_index') % 6 > 0)
  &
  (col('row_index') % 6 < 5)
  )
data = data.drop('_c0', '_c16', 'row_index')

for i, header in enumerate(headers):
  data = data.withColumnRenamed(f'_c{i+1}', header.strip())

display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ANNUAL</th><th>JAN</th><th>FEB</th><th>MAR</th><th>APR</th><th>MAY</th><th>JUN</th><th>JUL</th><th>AUG</th><th>SEP</th><th>OCT</th><th>NOV</th><th>DEC</th><th>YEARS</th><th>N_CITIES</th></tr></thead><tbody><tr><td>36.8</td><td>10.6</td><td>15.8</td><td>25.3</td><td>39.1</td><td>49.5</td><td>56.7</td><td>60.9</td><td>59.2</td><td>50</td><td>39.2</td><
><tr><td>31.2</td><td>4.7</td><td>6.6</td><td>17</td><td>29.1</td><td>39.1</td><td>48.4</td><td>54.5</td><td>53.3</td><td>45.5</td><td>35.9</td><td>26.8</td><td>13.1</td><td>25</td><td>81</td></tr><tr><td>44.4</td><td>4</td><td>3</td><td>3.6</td><td>3.4</td><td>3.8</td><td>3.6</td><td>3.8</td><td>3.6</td><td>3.6</td><td>3.9</td><td>4.2</td><td>3.9</td><td>25</td><td>77</td></tr><tr><td>37.9</td><td>18</td><td>17.4</td><td>24</td><td>33.4</td><td>42.2</td><td>50.2</td><td>58.1</td><td>58.9</td><td>52.1</td><td>42.9</td><td>33.9</td><td>24.5</td><td>26</td><td>132</td></tr><tr><td>45.5</td><td>25.8</td><td>25.7</td><td>31.8</td><td>40.5</td><td>50.4</td><td>59.1</td><td>66.8</td><td>67.2</td><td>60</td><td>49.5</td><td>39.9</td><td>31</td><td>25</td><td>127</td></tr><tr><td>30.9</td><td>11</td><td>9.9</td><td>16.8</td><td>27</td><td>34.5</td><td>41.9</td><td>50</td><td>51.2</td><td>44.8</td><td>36.6</td><td>28.5</td><td>18.6</td><t ...

# %%
multi_index = provinces.crossJoin(measurements)
display(multi_index)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Province</th><th>Measurement</th></tr></thead><tbody><tr><td>Alberta</td><td>Average Temperature (F)</td></tr><tr><td>Alberta</td><td>Average High Temperature (F)</td></tr><tr><td>Alberta</td><td>Average Low Temperature (F)</td></tr><tr><td>Alberta</td><td>Average Precipitation (in)</td></tr><tr><td>British Columbia</td><td>Average Temperature (F)</td></tr><tr><td>British Columbia</td><td>Average High Temperature (F)</td></tr><tr><td>British Columbia</td><td>Average Low Temperature (F)</td></tr><tr><td>British Columbia</td><td>Average Precipitation (in)</td></tr><tr><td>Manitoba</td><td>Average Temperature (F)</td></tr><tr><td>Manitoba</td><td>Average High Temperature (F)</td></tr><tr><td>Manitoba</td><td>Average Low Temperature (F)</td></tr><tr><td>Manitoba</td><td>Average Precipitation (in)</td></tr><tr><td>New Brunswick</td><td>Average Temperature (F)</td></tr><tr><td>New Brunswick</td><td>Average High Temperature (F)</td></tr><tr><td>New Brunswick</td><td>Average Low Temperature (F)</td></tr><tr><td>New Brunswick</td><td>Average Precipitation (in)</td></tr><tr><td>Newfoundland</td><td>Average Temperature (F)</td></tr><tr><td>Newfoundland</td><td>Average High Temperature (F)</td></tr><tr><td>Newfoundland</td><td>Average Low Temperature (F)</td></tr><tr><td>Newfoundland</td><td>Average Precipitation (in)</td></tr><tr><td>Northwest Territories</td><td>Average Temperature (F)</td></tr><tr><td>Northwest Territories</td><td>Average High Temperature (F)</td></tr><tr><td>Northwest Territories</td><td>Average Low Temperature (F)</td></tr><tr><td>Northwest Territories</td><td>Average Precipitation (in)</td></tr><tr><td>Nova Scotia</td><td>Average Temperature (F)</td></tr><tr><td>Nova Scotia</td><td>Average High Temperature (F)</td></tr><tr><td>Nova Scotia</td><td>Average Low Temperature (F)</td></tr><tr><td>Nova Scotia</td><td>Average Precipitation (in)</td></tr><tr><td>Nunavut</td><td>Average Temperature (F)</td></tr><tr><td>Nunavut</td><td>Average High Temperature (F)</td></tr><tr><td>Nunavut</td><td>Average Low Temperature (F)</td></tr><tr><td>Nunavut</td><td>Average Precipitation (in)</td></tr><tr><td>Ontario</td><td>Average Temperature (F)</td></tr><tr><td>Ontario</td><td>Average High Temperature (F)</td></tr><tr><td>Ontario</td><td>Average Low Temperature (F)</td></tr><tr><td>Ontario</td><td>Average Precipitation (in)</td></tr><tr><td>Prince Edward Island</td><td>Average Temperature (F)</td></tr><tr><td>Prince Edward Island</td><td>Average High Temperature (F)</td></tr><tr><td>Prince Edward Island</td><td>Average Low Temperature (F)</td></tr><tr><td>Prince Edward Island</td><td>Average Precipitation (in)</td></tr><tr><td>Quebec</td><td>Average Temperature (F)</td></tr><tr><td>Quebec</td><td>Average High Temperature (F)</td></tr><tr><td>Quebec</td><td>Average Low Temperature (F)</td></tr><tr><td>Quebec</td><td>Average Precipitation (in)</td></tr><tr><td>Saskatchewan</td><td>Average Temperature (F)</td></tr><tr><td>Saskatchewan</td><td>Average High Temperature (F)</td></tr><tr><td>Saskatchewan</td><td>Average Low Temperature (F)</td></tr><tr><td>Saskatchewan</td><td>Average Precipitation (in)</td></tr><tr><td>Yukon</td><td>Average Temperature (F)</td></tr><tr><td>Yukon</td><td>Average High Temperature (F)</td></tr><tr><td>Yukon</td><td>Average Low Temperature (F)</td></tr><tr><td>Yukon</td><td>Average Precipitation (in)</td></tr></tbody></table></div>

# %% [markdown]
# ## Create DataFrame with multi-index for organization's sake

# %%
multi_index = multi_index.withColumn("row_index", monotonically_increasing_id())
full_data = data.withColumn("row_index", monotonically_increasing_id())

full_data = multi_index.join(full_data, on="row_index").drop("row_index")

for header in headers:
  full_data = full_data.withColumn(header, full_data[header].cast('double'))

display(full_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Province</th><th>Measurement</th><th>ANNUAL</th><th>JAN</th><th>FEB</th><th>MAR</th><th>APR</th><th>MAY</th><th>JUN</th><th>JUL</th><th>AUG</th><th>SEP</th><th>OCT</th><th>NOV</th><th>DEC</th><th>YEARS</th><th>N_CITIES</th></tr></thead><tbody><tr><td>Alberta</td><td>Average Temperature (F)</td><td>36.8</td><td>10.6</td><td>15.8</td><td>25.3</td><td>39.1</td><td>49.5</td><td>56.7</td><td>60.9</td><td>59.2</td><td>50.0</td><td>39.2</td><td>23.3</td><td>13.8</td><td>24.0</td><td>245.0</td></tr><tr><td>Alberta</td><td>Average High Temperature (F)</td><td>48.3</td><td>21.2</td><td>27.0</td><td>36.2</td><td>51.2</td><td>62.1</td><td>68.8</td><td>73.6</td><td>72.3</td><td>62.5</td><td>50.6</td><td>32.6</td><td>23.8</td><td>25.0</td><td>236.0</td></tr><tr><td>Alberta</td><td>Average Low Temperature (F)</td><td>25.8</td><td>0.9</td><td>5.0</td><td>14.5</td><td>27.4</td><td>36.9</td><td>44.7</td><td>48.5</td><td>46.4</td><td>37.7</td><td>28.2</td><td>14.1</td><td>4.4</td><td>25.0</td><td>236.0</td></tr><tr><td>Alberta</td><td>Average Precipitation (in)</td><td>18.2</td><td>0.9</td><td>0.7</td><td>0.9</td><td>1.1</td><td>2.0</td><td>3.2</td><td>3.0</td><td>2.3</td><td>1.7</td><td>0.9</td><td>0.9</td><
# ## Weight values by `N_CITIES` column

# %%
non_numerical_cols = ["Province", "Measurement", "YEARS", "N_CITIES"]
numerical_cols = [c for c in full_data.columns if c not in non_numerical_cols]

meas_df = full_data
for numerical_col in numerical_cols:
  meas_df = meas_df.withColumn(f'WEIGHTED_{numerical_col}', col(numerical_col) * col('N_CITIES'))
  meas_df = meas_df.drop(numerical_col)

meas_df = meas_df.drop('Province', 'YEARS')
display(meas_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Measurement</th><th>N_CITIES</th><th>WEIGHTED_ANNUAL</th><th>WEIGHTED_JAN</th><th>WEIGHTED_FEB</th><th>WEIGHTED_MAR</th><th>WEIGHTED_APR</th><th>WEIGHTED_MAY</th><th>WEIGHTED_JUN</th><th>WEIGHTED_JUL</th><th>WEIGHTED_AUG</th><th>WEIGHTED_SEP</th><th>WEIGHTED_OCT</th><th>WEIGHTED_NOV</th><th>WEIGHTED_DEC</th></tr></thead><tbody><tr><td>Average Temperature (F)</td><td>245.0</td><td>9016.0</td><td>2597.0</td><td>3871.0</td><td>6198.5</td><td>9579.5</td><td>12127.5</td><td>13891.5</td><td>14920.5</td><td>14504.0</td><td>12250.0</td><td>9604.0</td><td>5708.5</td><td>3381.0</td></tr><tr><td>Average Temperature (F)</td><td>236.0</td><td>11398.8</td><td>5003.2</td><td>6372.0</td><td>8543.2</td><td>12083.2</td><td>14655.6</td><td>16236.8</td><td>17369.6</td><td>17062.8</td><td>14750.0</td><td>11941.6</td><td>7693.6</td><td>5616.8</td></tr><tr><td>Average Temperature (F)</td><td>236.0</td><td>6088.8</td><td>212.4</td><td>1180.0</td><td>3422.0</td><td>6466.4</td><td>8708.4</td><td>10549.2</td><td>11446.0</td><td>10950.4</td><td>8897.2</td><td>6655.2</td><td>3327.6</td><td>1038.4</td></tr><tr><td>Average Temperature (F)</td><td>277.0</td><td>5041.4</td><td>249.3</td><td>193.89999999999998</td><td>249.3</td><td>304.70000000000005</td><td>554.0</td><td>886.4000000000001</td><td>831.0</td><td>637.0999999999999</td><td>470.9</td><td>249.3</td><td>249.3</td><td>221.60000000000002</td></tr><tr><td>Average Temperature (F)</td><td>471.0</td><td>20582.7</td><td>12811.199999999999</td><td>14365.5</td><td>17285.7</td><td>20629.8</td><td>23973.899999999998</td><td>26752.8</td><td>28825.2</td><td>28636.8</td><td>25434.0</td><td>20865.3</td><td>16014.0</td><td>12952.5</td></tr><tr><td>Average Temperature (F)</td><td>469.0</td><td>24481.800000000003</td><td>15430.099999999999</td><td>17634.4</td><td>21151.9</td><td>25091.5</td><td>28749.699999999997</td><td>31469.899999999998</td><td>33861.8</td><td>33768.0</td><td>30156.699999999997</td><td>24388.0</td><td>18478.6</td><td>15383.199999999999</td></tr><tr><td>Average Temperature (F)</td><td>469.0</td><td>16508.800000000003</td><td>10083.5</td><td>10974.599999999999</td><td>13225.8</td><td>15992.900000000001</td><td>19041.4</td><td>21808.5</td><td>23496.9</td><td>23215.5</td><td>20495.300000000003</td><td>17212.300000000003</td><td>13366.5</td><td>10458.7</td></tr><tr><td>Average Temperature (F)</td><td>517.0</td><td>25333.0</td><td>3670.7</td><td>2223.1</td><td>2068.0</td><td>1706.1</td><td>1447.6</td><td>1447.6</td><td>1137.4</td><td>1137.4</td><td>1499.3</td><td>2740.1</td><td>3567.3</td><td>3205.4</td></tr><tr><td>Average Temperature (F)</td><td>144.0</td><td>4982.400000000001</td><td>-43.199999999999996</td><td>849.6</td><td>2664.0</td><td>5212.8</td><td>7156.8</td><td>8582.4</td><td>9316.800000000001</td><td>9057.6</td><td>7502.400000000001</td><td>5630.400000000001</td><td>2980.7999999999997</td><td>806.4</td></tr><tr><td>Average Temperature (F)</td><td>140.0</td><td>6244.0</td><td>1288.0</td><td>2226.0</td><td>3990.0</td><td>6594.0</td><td>8624.0</td><td>9898.0</td><td>10612.0</td><td>10416.0</td><td>8764.0</td><td>6734.0</td><td>3962.0</td><td>1974.0</td></tr><tr><td>Average Temperature (F)</td><td>140.0</td><td>3430.0</td><td>-1358.0</td><td>-560.0</td><td>1204.0</td><td>3542.0</td><td>5306.0</td><td>6790.0</td><td>7490.0</td><td>7182.0</td><td>5796.0</td><td>4200.0</td><td>1834.0</td><td>-392.0</td></tr><tr><td>Average Temperature (F)</td><td>181.0</td><td>3692.3999999999996</td><td>162.9</td><td>126.69999999999999</td><td>181.0</td><td>199.10000000000002</td><td>398.20000000000005</td><td>597.3</td><td>543.0</td><td>488.70000000000005</td><td>380.1</td><td>271.5</td><td>199.10000000000002</td><td>181.0</td></tr><tr><td>Average Temperature (F)</td><td>83.0</td><td>3361.5</td><td>1162.0</td><td>1369.5</td><td>2174.6</td><td>3137.3999999999996</td><td>4133.4</td><td>4913.6</td><t ...

# %% [markdown]
# ## Group by `Measurement` column and take the weighted average

# %%
result_df = meas_df.groupBy("Measurement").sum()
for field in result_df.schema.fields:

  if field.name not in ['Measurement', 'sum(N_CITIES)']:
    result_df = result_df.withColumn(f'avg({field.name.removeprefix("sum(WEIGHTED_").removesuffix(")")})', col(field.name) / col('sum(N_CITIES)'))
    result_df = result_df.drop(field.name)

result_df = result_df.drop('sum(N_CITIES)')
result_df = result_df.filter((col('Measurement') == 'Average Temperature (F)') | (col('Measurement') == 'Average Precipitation (in)'))
display(result_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Measurement</th><th>avg(ANNUAL)</th><th>avg(JAN)</th><th>avg(FEB)</th><th>avg(MAR)</th><th>avg(APR)</th><th>avg(MAY)</th><th>avg(JUN)</th><th>avg(JUL)</th><th>avg(AUG)</th><th>avg(SEP)</th><th>avg(OCT)</th><th>avg(NOV)</th><th>avg(DEC)</th></tr></thead><tbody><tr><td>Average Temperature (F)</td><td>38.84745011086475</td><td>14.209839246119733</td><td>16.85873059866962</td><td>22.82649667405765</td><td>30.637305986696234</td><td>37.38262195121951</td><td>42.63414634146341</td><td>45.797366962305986</td><td>44.99539911308204</td><td>39.07818736141907</td><td>31.650083148558757</td><td>22.222394678492243</td><td>15.679046563192905</td></tr><tr><td>Average Precipitation (in)</td><td>34.69959394610557</td><td>4.680324843115541</td><td>7.785529715762274</td><td>16.088261351052047</td><td>27.43831672203765</td><td>36.7531561461794</td><td>43.69579180509413</td><td>47.362643041712815</td><td>45.83252122554448</td><td>38.91328903654485</td><td>30.0608711701735</td><td>19.47626430417128</td><td>9.435289774824662</td></tr></tbody></table></div>
