# %% [markdown]
# # Q3)

# %% [markdown]
# ### Design a genetic algorithm to solve the polynomial fitting problem that we did in Homework #1. You need to implement a genetic algorithm using BOTH mutation AND crossover operations. You need to decide a mutation rate and a crossover rate.
#
# ### Plot the following in one figure: 1) the original noisy data, 2) the polynomial you obtained in  Homework  #1,  and  3)  the  polynomial  obtained  from  this  implementation.  Compare  and  discussion the difference in performance of the two polynomials obtained with two different  methods.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
# FROM HW 1
plt.style.use('seaborn-whitegrid') 

noise_scale = 100 
number_of_samples = 50 

x =  25*(np.random.rand(number_of_samples, 1) - 0.5) 
y = 5 * x + 15 * x**2 + 2 * x**3 + noise_scale*np.random.randn(number_of_samples, 1) 

plt.plot(x,y,'ro')
# Out:
# C:\Users\wyatt\AppData\Local\Temp\ipykernel_19560\18227241.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
class GeneticAlgorithm:
    
    def __init__(self, fitness, fitness_threshold, p, r, m, M, crossover_operator, take_min_fitness=True):
        
        self.fitness = fitness
        self.fitness_threshold = fitness_threshold
        
        self.crossover_operator = {
            
            'Simple Arithmetic Crossover': self.CrossoverOperator_simple_arithmetic_crossover,
            'Average': self.CrossoverOperator_average,
            'Single Arithmetic Crossover': self.CrossoverOperator_single_arithmetic_crossover,
            'Whole Arithmetic Crossover': self.CrossoverOperator_whole_arithmetic_crossover,
            
        }[crossover_operator]
        
        self.p = p
        self.r = r
        self.m = m

        self.f = f
        self.M = M
        
        self.scale = 50
        
        self.P = self.intialize_population()
        self.evaluations = self.evaluate()
        
        self.take_min_fitness = take_min_fitness
        self.best_fitness, self.best_h = self.determine_best_h()
        
        self.log = {
            'iteration #': [-1],
            'size of P': [self.P.shape[0]],
            'best fitness': [self.best_fitness],
            'best hypothesis': [self.best_h]
        }
    
    def CrossoverOperator(self):
        
        P = self.P
        r = self.r
        p = P.shape[0]
        
        num_parents = math.ceil(r*p)
        
        Pr_P = [self.Pr(h) for h in P]
        P_parent_indicies = np.random.choice(range(p), replace=False, size=num_parents, p=Pr_P)
        P_parents = P[P_parent_indicies]
        
        P_parents1 = P_parents[:int(num_parents/2)]
        P_parents2 = P_parents[int(num_parents/2):]
        couples = zip(P_parents1, P_parents2)
        
        return self.crossover_operator(couples)
    
    def CrossoverOperator_whole_arithmetic_crossover(self, couples):
        
        children = []
        
        for couple in couples:
            parent1, parent2 = couple
            alpha = np.random.randint(0, self.M-1)
            
            offspring1 = parent1 * alpha + parent2 * (1-alpha)
            offspring2 = parent2 * alpha + parent1 * (1-alpha)
            
            assert len(parent1) == len(parent2) == len(offspring1) == len(offspring2)

            children.append(offspring1)
            children.append(offspring2)
        
        return children
    
    def CrossoverOperator_single_arithmetic_crossover(self, couples):
        
        children = []
        
        for couple in couples:
            parent1, parent2 = couple
            alpha = np.random.randint(0, self.M-1)
            
            offspring1 = np.append(parent1[:alpha], [parent2[alpha]], parent1[alpha+1:])
            offspring2 = np.append(parent2[:alpha], [parent1[alpha]], parent2[alpha+1:])
            
            assert len(parent1) == len(parent2) == len(offspring1) == len(offspring2)

            children.append(offspring1)
            children.append(offspring2)
        
        return children
    
    
    def CrossoverOperator_simple_arithmetic_crossover(self, couples):
        
        children = []
        
        for couple in couples:
            parent1, parent2 = couple
            cutoff = np.random.randint(0, self.M-1)
            
            offspring1 = np.append(parent1[:cutoff], parent2[cutoff:])
            offspring2 = np.append(parent2[:cutoff], parent1[cutoff:])
            
            assert len(parent1) == len(parent2) == len(offspring1) == len(offspring2)

            children.append(offspring1)
            children.append(offspring2)
        
        return children
    
    def CrossoverOperator_average(self, couples):
        
        children = []
        
        for couple in couples:
            parent1, parent2 = couple
            weight = np.random.random()
            
            offspring1 = (
                np.array(parent1)*(weight) + np.array(parent2)* (1-weight)
            ) * 0.5
            offspring2 = (
                np.array(parent2)*(weight) + np.array(parent1)* (1-weight)
            ) * 0.5
            
            assert len(parent1) == len(parent2) == len(offspring1) == len(offspring2)
            
            children.append(offspring1)
            children.append(offspring2)

        return children
    
    def determine_best_h(self):
        
        evaluations = self.evaluate()
        
        if self.take_min_fitness:
            best_fitness, best_h = min(zip(evaluations, self.P), key=lambda x: x[0])
        else:
            best_fitness, best_h = max(zip(evaluations, self.P), key=lambda x: x[0])

        return best_fitness, best_h
    
    def evaluate(self):
        
        evaluations = np.array([
            self.fitness(h)
            for h in self.P
        ])
        
        return evaluations
            
    
    def intialize_population(self):
        
        P = self.scale * np.random.random(size=(self.p, self.M))
        return P
        
    def Pr(self, h):
        
        return self.fitness(h) / sum(self.fitness(h_j) for h_j in self.P)
    
    def select(self):
        
        P = self.P
        Pr_P = [self.Pr(h) for h in P]
        
        p = P.shape[0]
        r = self.r
        
        num_selected = math.ceil((1-r)*p)
        
        Ps_indicies = np.random.choice(range(p), replace=False, size=num_selected, p=Pr_P)
        Ps = P[Ps_indicies]
        
        return Ps
    
    def mutate(self, P):
        
        p = P.shape[0]
        num_mutations = math.ceil(self.m * p)
        
        mutant_indicies = np.random.choice(range(p), replace=False, size=num_mutations)
        
        for i in mutant_indicies:
            
            mutation_strength = self.scale * np.random.random() * (-1 ** np.random.randint(0, 1))
            mutation_index = np.random.randint(self.M)
            
            P[i][mutation_index] += mutation_strength
            
        return P
            
    
    def run(self):
        iterations = -1
        
        if self.take_min_fitness:
            continue_cond = lambda : self.best_fitness > self.fitness_threshold
        else:
            continue_cond = lambda : self.best_fitness < self.fitness_threshold

        while continue_cond() and iterations < 1000:
            
#             print(self.P.shape)
            
            # 1) Select
            Ps = self.select()
#             print(self.P.shape, Ps.shape)
            
            # 2) Crossover
            offspring = np.array(self.CrossoverOperator())            
            
#             print(self.P.shape, Ps.shape, offspring.shape)
                        
            # 3) Mutate
            offspring = self.mutate(offspring)
#             print(self.P.shape, Ps.shape, offspring.shape)
            
            # 4) Update
            Ps = np.array(Ps.tolist() + offspring.tolist())
            self.P = Ps
#             print(self.P.shape, Ps.shape, offspring.shape)
            
            # 5) Evaluate
            best_fitness, best_h = self.determine_best_h()
            
#             print('='*50)
            
            self.best_fitness = best_fitness
            self.best_h = best_h
            
            iterations += 1
            if iterations % 1 == 0:
                
                print(
                    "ITER. # %i:"
                    " Size of P: %s"
                    "| Best Fitness: %1.5e "
                    "| Best Hypothesis: %s" % (iterations, self.P.shape[0], self.best_fitness, self.best_h),
                    end = '\n'+'='*50 + '\n'
                )
                
                self.log['iteration #'].append(iterations)
                self.log['size of P'].append(self.P.shape[0])
                self.log['best fitness'].append(best_fitness)
                self.log['best hypothesis'].append(best_h)

        return best_h

# %%
fitness_threshold = 1

p = 500
r = 1
m = 0.01

x = x.reshape((-1))
M = 3

# %%
# crossover_operator = 'Simple Arithmetic Crossover'
# crossover_operator = 'Whole Arithmetic Crossover'
crossover_operator = 'Average'

# %%
def f(x, w):
    
    g = np.array([
        x**1, 
        x**2,  
        x**3
    ])
    
    return w @ g

def fitness(w):
    
    y_predicted = f(x, w)
    r = (y - y_predicted)**2

    return r.sum()

# %%
GA = GeneticAlgorithm(
    fitness=fitness, 
    fitness_threshold=fitness_threshold, 
    p=p, 
    r=r, 
    m=m, 
    M=M, 
    crossover_operator=crossover_operator, 
    take_min_fitness=True
)

# %%
GA.run()
# Out:
# ITER. # 0: Size of P: 500| Best Fitness: 6.31207e+09 | Best Hypothesis: [8.510692   4.36601626 1.15355119]
# ==================================================
# ITER. # 1: Size of P: 500| Best Fitness: 6.52451e+09 | Best Hypothesis: [2.36541495 2.17494846 1.2563003 ]
# ==================================================
# ITER. # 2: Size of P: 500| Best Fitness: 5.42055e+09 | Best Hypothesis: [3.93138215 1.29357872 0.50383196]
# ==================================================
# ITER. # 3: Size of P: 500| Best Fitness: 5.31534e+09 | Best Hypothesis: [ 2.04434514  0.84932562 -0.40714875]
# ==================================================
# ITER. # 4: Size of P: 500| Best Fitness: 5.21147e+09 | Best Hypothesis: [ 0.84107427  0.74396705 -0.12137012]
# ==================================================
# ITER. # 5: Size of P: 500| Best Fitness: 5.24892e+09 | Best Hypothesis: [0.42320264 0.38779699 0.1055287 ]
# ==================================================
# ITER. # 6: Size of P: 500| Best Fitness: 5.25664e+09 | Best Hypothesis: [ 0.1928352   0.17441827 -0.01645518]
# ==================================================
# ITER. # 7: Size of P: 500| Best Fitness: 5.26455e+09 | Best Hypothesis: [ 0.09648747  0.09586586 -0.00803704]
# ==================================================
# ITER. # 8: Size of P: 500| Best Fitness: 5.26832e+09 | Best Hypothesis: [ 0.05338633  0.05820919 -0.01634658]
# ==================================================
# ITER. # 9: Size of P: 500| Best Fitness: 5.27105e+09 | Best Hypothesis: [-4.13094177  0.02573446  0.02632204]
# ==================================================
# ITER. # 10: Size of P: 500| Best Fitness: 5.27277e+09 | Best Hypothesis: [-4.13917383  0.01067972  0.01070644]
# ==================================================
# ITER. # 11: Size of P: 500| Best Fitness: 5.27318e+09 | Best Hypothesis: [-3.07073955  0.00663498  0.00549066]
# ==================================================
# ITER. # 12: Size of P: 500| Best Fitness: 5.27367e+09 | Best Hypothesis: [-1.46570344  0.00321377  0.0027572 ]
# ==================================================
# ITER. # 13: Size of P: 500| Best Fitness: 5.27378e+09 | Best Hypothesis: [-1.84275988e+00  1.50383524e-03  1.53498669e-03]
# ==================================================
# ITER. # 14: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-2.44718583e+00 -5.51245549e-04  8.31902394e-05]
# ==================================================
# ITER. # 15: Size of P: 500| Best Fitness: 5.27404e+09 | Best Hypothesis: [-2.89661643e+00  2.93338811e-05 -3.58814808e-03]
# ==================================================
# ITER. # 16: Size of P: 500| Best Fitness: 5.27403e+09 | Best Hypothesis: [-1.22801221e+00  3.45382319e-05 -1.58095435e-03]
# ==================================================
# ITER. # 17: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-2.00294102e+00 -1.93791619e-04 -4.00839932e-03]
# ==================================================
# ITER. # 18: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-1.87490349e+00 -1.00451515e-04 -2.44448447e-04]
# ==================================================
# ITER. # 19: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-2.65890940e+00 -1.38484927e-04 -3.48668646e-04]
# ==================================================
# ITER. # 20: Size of P: 500| Best Fitness: 5.27404e+09 | Best Hypothesis: [-1.26582430e+00 -7.67992516e-05 -1.66909222e-04]
# ==================================================
# ITER. # 21: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-1.86514455e+00 -5.56138833e-04 -8.34417481e-04]
# ==================================================
# ITER. # 22: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-1.52460326e+00 -1.19358317e-04 -2.33356464e-03]
# ==================================================
# ITER. # 23: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-1.41440583e+00 -1.29431199e-04 -5.38968826e-04]
# ==================================================
# ITER. # 24: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-1.66767954e+00 -3.79137242e-04 -1.77263895e-04]
# ==================================================
# ITER. # 25: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.15873184e+00 -4.36539926e-04 -6.33808074e-04]
# ==================================================
# ITER. # 26: Size of P: 500| Best Fitness: 5.27410e+09 | Best Hypothesis: [-1.11363553e+00 -3.63031594e-04 -8.24759247e-05]
# ==================================================
# ITER. # 27: Size of P: 500| Best Fitness: 5.27412e+09 | Best Hypothesis: [-1.52456099e+00 -1.27293125e-03 -2.89124719e-03]
# ==================================================
# ITER. # 28: Size of P: 500| Best Fitness: 5.27407e+09 | Best Hypothesis: [-2.60136020e+00 -3.38608578e-04 -4.84403476e-03]
# ==================================================
# ITER. # 29: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.15848437e+00 -2.02905058e-04 -1.12331133e-03]
# ==================================================
# ITER. # 30: Size of P: 500| Best Fitness: 5.27411e+09 | Best Hypothesis: [-1.74154867e+00 -9.35478017e-04 -6.36424846e-03]
# ==================================================
# ITER. # 31: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-2.54240968e+00 -1.12744705e-04 -8.34647046e-04]
# ==================================================
# ITER. # 32: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-2.06218199e+00 -5.15693524e-04 -1.38749765e-05]
# ==================================================
# ITER. # 33: Size of P: 500| Best Fitness: 5.27403e+09 | Best Hypothesis: [-3.11573400e+00 -4.63814369e-04 -7.51205849e-05]
# ==================================================
# ITER. # 34: Size of P: 500| Best Fitness: 5.27409e+09 | Best Hypothesis: [-3.25702958e+00 -8.45349251e-04 -1.85429256e-04]
# ==================================================
# ITER. # 35: Size of P: 500| Best Fitness: 5.27410e+09 | Best Hypothesis: [-1.46381646e+00 -1.08790849e-03 -3.85197588e-05]
# ==================================================
# ITER. # 36: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-1.72531386e+00 -3.72328593e-04 -1.81361943e-03]
# ==================================================
# ITER. # 37: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.04183565e+00 -6.95082976e-05 -2.07747438e-03]
# ==================================================
# ITER. # 38: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-1.94508574e+00 -5.69122895e-05 -1.92705932e-03]
# ==================================================
# ITER. # 39: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-1.85610015e+00 -1.28151246e-04 -2.37275594e-04]
# ==================================================
# ITER. # 40: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-1.97911013e+00 -4.82067114e-05 -2.45741563e-04]
# ==================================================
# ITER. # 41: Size of P: 500| Best Fitness: 5.27424e+09 | Best Hypothesis: [-9.97015408e-02 -3.13258306e-05 -1.13489217e-02]
# ==================================================
# ITER. # 42: Size of P: 500| Best Fitness: 5.27393e+09 | Best Hypothesis: [-2.35645124e+00 -3.90451585e-05 -8.59249986e-05]
# ==================================================
# ITER. # 43: Size of P: 500| Best Fitness: 5.27404e+09 | Best Hypothesis: [-1.19696981e+00 -2.51996362e-05 -4.33204629e-04]
# ==================================================
# ITER. # 44: Size of P: 500| Best Fitness: 5.27407e+09 | Best Hypothesis: [-1.06308994e+00 -4.97391472e-05 -1.16501553e-03]
# ==================================================
# ITER. # 45: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-2.87739779e+00 -2.84875740e-04 -9.24662269e-05]
# ==================================================
# ITER. # 46: Size of P: 500| Best Fitness: 5.27405e+09 | Best Hypothesis: [-2.76099829e+00 -7.76473605e-04 -1.57851533e-03]
# ==================================================
# ITER. # 47: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.29384643e+00 -3.84190456e-04 -1.43642389e-04]
# ==================================================
# ITER. # 48: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-1.98130164e+00 -6.18655483e-04 -6.98403616e-04]
# ==================================================
# ITER. # 49: Size of P: 500| Best Fitness: 5.27403e+09 | Best Hypothesis: [-2.85024195e+00 -6.81776571e-04 -4.88448438e-04]
# ==================================================
# ITER. # 50: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-2.36457442e+00 -4.97446914e-04 -6.21314471e-04]
# ==================================================
# ITER. # 51: Size of P: 500| Best Fitness: 5.27403e+09 | Best Hypothesis: [-1.49263658e+00 -4.01861132e-04 -3.45212532e-05]
# ==================================================
# ITER. # 52: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.01269696e+00 -9.39342382e-05 -2.09867787e-04]
# ==================================================
# ITER. # 53: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-2.42858863e+00 -1.83636216e-04 -3.68175998e-03]
# ==================================================
# ITER. # 54: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.98505054e+00 -3.70549819e-05 -5.78286789e-05]
# ==================================================
# ITER. # 55: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.62577732e+00 -8.69863384e-05 -2.75087539e-03]
# ==================================================
# ITER. # 56: Size of P: 500| Best Fitness: 5.27406e+09 | Best Hypothesis: [-1.45524593e+00 -6.50558669e-04 -3.26375121e-05]
# ==================================================
# ITER. # 57: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-1.92700044e+00 -1.63455499e-04 -1.99514048e-04]
# ==================================================
# ITER. # 58: Size of P: 500| Best Fitness: 5.27410e+09 | Best Hypothesis: [-3.48935426e+00 -4.33228181e-04 -1.98161980e-04]
# ==================================================
# ITER. # 59: Size of P: 500| Best Fitness: 5.27407e+09 | Best Hypothesis: [-1.20085332e+00 -2.31383572e-04 -3.80009274e-05]
# ==================================================
# ITER. # 60: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-2.58492019e+00 -1.98465079e-04 -5.96228173e-05]
# ==================================================
# ITER. # 61: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-1.71081001e+00 -2.51149664e-04 -2.28779489e-05]
# ==================================================
# ITER. # 62: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.54004169e+00 -9.76657746e-05 -3.22978924e-05]
# ==================================================
# ITER. # 63: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-2.15146680e+00 -6.32959386e-04 -1.38401061e-05]
# ==================================================
# ITER. # 64: Size of P: 500| Best Fitness: 5.27402e+09 | Best Hypothesis: [-3.25133273e+00 -1.71611682e-04 -2.46239384e-04]
# ==================================================
# ITER. # 65: Size of P: 500| Best Fitness: 5.27408e+09 | Best Hypothesis: [-1.08800938e+00 -1.29579974e-04 -1.35549829e-04]
# ==================================================
# ITER. # 66: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.03181667e+00 -2.54191390e-04 -1.59226092e-04]
# ==================================================
# ITER. # 67: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.56876425e+00 -1.65541665e-04 -1.68612337e-04]
# ==================================================
# ITER. # 68: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.60123091e+00 -1.86495112e-04 -3.91032140e-04]
# ==================================================
# ITER. # 69: Size of P: 500| Best Fitness: 5.27410e+09 | Best Hypothesis: [-2.60662827e+00 -1.66372152e-03 -6.12981652e-05]
# ==================================================
# ITER. # 70: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.89933503e+00 -4.40574642e-04 -3.77086774e-04]
# ==================================================
# ITER. # 71: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-2.74008930e+00 -6.86468648e-05 -2.42032321e-04]
# ==================================================
# ITER. # 72: Size of P: 500| Best Fitness: 5.27414e+09 | Best Hypothesis: [-8.23838033e-01 -1.05074639e-04 -3.61745313e-04]
# ==================================================
# ITER. # 73: Size of P: 500| Best Fitness: 5.27428e+09 | Best Hypothesis: [-9.23684333e-05 -5.05990525e-05 -9.02023263e-03]
# ==================================================
# ITER. # 74: Size of P: 500| Best Fitness: 5.27426e+09 | Best Hypothesis: [-0.00023988 -0.00011706 -0.01498016]
# ==================================================
# ITER. # 75: Size of P: 500| Best Fitness: 5.27415e+09 | Best Hypothesis: [-6.79213346e-01 -9.20779224e-05 -3.28288859e-03]
# ==================================================
# ITER. # 76: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.29012888e+00 -1.29455905e-04 -2.05075630e-03]
# ==================================================
# ITER. # 77: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.52193595e+00 -2.91514112e-04 -1.98975325e-04]
# ==================================================
# ITER. # 78: Size of P: 500| Best Fitness: 5.27404e+09 | Best Hypothesis: [-2.19090580e+00 -1.14726487e-03 -4.36147424e-04]
# ==================================================
# ITER. # 79: Size of P: 500| Best Fitness: 5.27417e+09 | Best Hypothesis: [-1.04991925e+00 -9.41484921e-04 -2.14035211e-04]
# ==================================================
# ITER. # 80: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-1.82100311e+00 -3.35890972e-04 -5.17519951e-05]
# ==================================================
# ITER. # 81: Size of P: 500| Best Fitness: 5.27404e+09 | Best Hypothesis: [-1.37294332e+00 -2.86206098e-04 -1.22277094e-03]
# ==================================================
# ITER. # 82: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.52835539e+00 -4.12234470e-04 -1.53766388e-04]
# ==================================================
# ITER. # 83: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-2.40068506e+00 -2.16508048e-04 -4.11123872e-04]
# ==================================================
# ITER. # 84: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-1.73422996e+00 -1.60566943e-04 -1.93296850e-04]
# ==================================================
# ITER. # 85: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.65407409e+00 -4.93212053e-05 -2.76352275e-04]
# ==================================================
# ITER. # 86: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-1.97519993e+00 -2.49056210e-04 -1.16443843e-03]
# ==================================================
# ITER. # 87: Size of P: 500| Best Fitness: 5.27418e+09 | Best Hypothesis: [-8.13645115e-01 -2.89478440e-04 -1.47469307e-02]
# ==================================================
# ITER. # 88: Size of P: 500| Best Fitness: 5.27425e+09 | Best Hypothesis: [-2.93590678e-01 -1.75846489e-04 -5.35071440e-03]
# ==================================================
# ITER. # 89: Size of P: 500| Best Fitness: 5.27424e+09 | Best Hypothesis: [-0.31498344 -0.00046641 -0.01343214]
# ==================================================
# ITER. # 90: Size of P: 500| Best Fitness: 5.27418e+09 | Best Hypothesis: [-1.69895798e+00 -2.11651931e-03 -7.08963242e-05]
# ==================================================
# ITER. # 91: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-2.71003338e+00 -7.48135794e-04 -5.31260105e-05]
# ==================================================
# ITER. # 92: Size of P: 500| Best Fitness: 5.27406e+09 | Best Hypothesis: [-1.32978331e+00 -4.61131940e-04 -8.45412482e-05]
# ==================================================
# ITER. # 93: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.92580775e+00 -1.22347857e-04 -4.10500475e-03]
# ==================================================
# ITER. # 94: Size of P: 500| Best Fitness: 5.27402e+09 | Best Hypothesis: [-2.07748412e+00 -8.67943166e-04 -2.41888100e-04]
# ==================================================
# ITER. # 95: Size of P: 500| Best Fitness: 5.27402e+09 | Best Hypothesis: [-1.87563293e+00 -7.76715850e-04 -7.41486907e-05]
# ==================================================
# ITER. # 96: Size of P: 500| Best Fitness: 5.27409e+09 | Best Hypothesis: [-1.17329661e+00 -4.51290576e-04 -9.88125766e-04]
# ==================================================
# ITER. # 97: Size of P: 500| Best Fitness: 5.27412e+09 | Best Hypothesis: [-2.70564211e+00 -1.80906931e-03 -1.18680204e-04]
# ==================================================
# ITER. # 98: Size of P: 500| Best Fitness: 5.27405e+09 | Best Hypothesis: [-2.07777936e+00 -1.15294411e-03 -6.02336069e-04]
# ==================================================
# ITER. # 99: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-2.72002507e+00 -6.32445989e-05 -5.59724624e-04]
# ==================================================
# ITER. # 100: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-2.30130862e+00 -8.84009069e-05 -1.70352902e-03]
# ==================================================
# ITER. # 101: Size of P: 500| Best Fitness: 5.27405e+09 | Best Hypothesis: [-1.29674980e+00 -2.82361346e-04 -1.71926663e-03]
# ==================================================
# ITER. # 102: Size of P: 500| Best Fitness: 5.27402e+09 | Best Hypothesis: [-1.82822412e+00 -6.91089748e-04 -1.15887767e-03]
# ==================================================
# ITER. # 103: Size of P: 500| Best Fitness: 5.27404e+09 | Best Hypothesis: [-1.55323228e+00 -5.20851161e-04 -1.79933751e-03]
# ==================================================
# ITER. # 104: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-1.72519996e+00 -1.31356708e-04 -2.90370823e-04]
# ==================================================
# ITER. # 105: Size of P: 500| Best Fitness: 5.27408e+09 | Best Hypothesis: [-1.22654780e+00 -1.26967628e-04 -9.17028530e-03]
# ==================================================
# ITER. # 106: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.87303924e+00 -3.58867774e-04 -1.95403621e-03]
# ==================================================
# ITER. # 107: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-2.64160095e+00 -4.35986469e-04 -3.46435675e-04]
# ==================================================
# ITER. # 108: Size of P: 500| Best Fitness: 5.27393e+09 | Best Hypothesis: [-2.48416741e+00 -3.50885136e-05 -4.47841843e-04]
# ==================================================
# ITER. # 109: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-1.69710329e+00 -3.91687471e-04 -2.01652089e-04]
# ==================================================
# ITER. # 110: Size of P: 500| Best Fitness: 5.27406e+09 | Best Hypothesis: [-3.49657737e+00 -4.15532254e-05 -1.91113412e-04]
# ==================================================
# ITER. # 111: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-1.85965238e+00 -3.39962006e-05 -2.16929048e-04]
# ==================================================
# ITER. # 112: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-1.78780900e+00 -1.44987700e-04 -8.64621578e-05]
# ==================================================
# ITER. # 113: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-1.70195071e+00 -1.12927564e-04 -3.89173642e-04]
# ==================================================
# ITER. # 114: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-1.53859498e+00 -1.64826026e-04 -1.08455191e-04]
# ==================================================
# ITER. # 115: Size of P: 500| Best Fitness: 5.27419e+09 | Best Hypothesis: [-6.67558564e-01 -2.36592135e-04 -1.54986876e-03]
# ==================================================
# ITER. # 116: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-1.60627975e+00 -9.18967107e-05 -1.08146022e-03]
# ==================================================
# ITER. # 117: Size of P: 500| Best Fitness: 5.27411e+09 | Best Hypothesis: [-2.17797141e+00 -1.81490211e-03 -9.81914841e-05]
# ==================================================
# ITER. # 118: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.33693785e+00 -1.46939616e-04 -3.58541545e-04]
# ==================================================
# ITER. # 119: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-2.01426216e+00 -4.78981168e-04 -8.32397871e-05]
# ==================================================
# ITER. # 120: Size of P: 500| Best Fitness: 5.27416e+09 | Best Hypothesis: [-7.30703460e-01 -4.94605219e-04 -6.69399531e-03]
# ==================================================
# ITER. # 121: Size of P: 500| Best Fitness: 5.27393e+09 | Best Hypothesis: [-2.21234994e+00 -4.53560740e-05 -1.32393208e-05]
# ==================================================
# ITER. # 122: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.55249109e+00 -1.43575254e-04 -2.36011632e-04]
# ==================================================
# ITER. # 123: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.65130391e+00 -1.08392858e-04 -1.26670738e-03]
# ==================================================
# ITER. # 124: Size of P: 500| Best Fitness: 5.27393e+09 | Best Hypothesis: [-2.15190535e+00 -5.22866806e-05 -4.68138003e-04]
# ==================================================
# ITER. # 125: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.41697929e+00 -1.38133017e-04 -3.90714409e-04]
# ==================================================
# ITER. # 126: Size of P: 500| Best Fitness: 5.27402e+09 | Best Hypothesis: [-2.28101477e+00 -9.08072375e-04 -5.68719402e-04]
# ==================================================
# ITER. # 127: Size of P: 500| Best Fitness: 5.27403e+09 | Best Hypothesis: [-1.51566712e+00 -4.51215102e-04 -2.08746510e-04]
# ==================================================
# ITER. # 128: Size of P: 500| Best Fitness: 5.27419e+09 | Best Hypothesis: [-1.1586576  -0.00138024 -0.00149847]
# ==================================================
# ITER. # 129: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.47728066e+00 -5.07828122e-05 -1.11906679e-04]
# ==================================================
# ITER. # 130: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-1.98195870e+00 -3.12599204e-04 -1.85801274e-04]
# ==================================================
# ITER. # 131: Size of P: 500| Best Fitness: 5.27418e+09 | Best Hypothesis: [-1.12142598e+00 -1.19051912e-03 -9.24648042e-04]
# ==================================================
# ITER. # 132: Size of P: 500| Best Fitness: 5.27405e+09 | Best Hypothesis: [-3.30188074e+00 -3.00953081e-04 -2.33539004e-04]
# ==================================================
# ITER. # 133: Size of P: 500| Best Fitness: 5.27411e+09 | Best Hypothesis: [-1.02524584e+00 -2.41646202e-04 -8.31978060e-05]
# ==================================================
# ITER. # 134: Size of P: 500| Best Fitness: 5.27426e+09 | Best Hypothesis: [-2.95476861e-01 -1.42555498e-04 -4.31098421e-03]
# ==================================================
# ITER. # 135: Size of P: 500| Best Fitness: 5.27411e+09 | Best Hypothesis: [-2.57195541e+00 -1.70924302e-03 -4.23359231e-04]
# ==================================================
# ITER. # 136: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-2.52438158e+00 -1.67127463e-04 -2.73542558e-03]
# ==================================================
# ITER. # 137: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.49565478e+00 -2.87978931e-04 -6.02940648e-04]
# ==================================================
# ITER. # 138: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.12106709e+00 -2.57249515e-04 -7.75979081e-04]
# ==================================================
# ITER. # 139: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-1.51198457e+00 -2.60138916e-04 -1.02305866e-03]
# ==================================================
# ITER. # 140: Size of P: 500| Best Fitness: 5.27403e+09 | Best Hypothesis: [-1.68843376e+00 -6.76252555e-04 -5.17957578e-04]
# ==================================================
# ITER. # 141: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-1.96371887e+00 -6.63045743e-04 -4.80966912e-04]
# ==================================================
# ITER. # 142: Size of P: 500| Best Fitness: 5.27418e+09 | Best Hypothesis: [-7.65549727e-01 -3.06959744e-04 -2.73371105e-04]
# ==================================================
# ITER. # 143: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.42879925e+00 -1.25267323e-04 -1.67505469e-04]
# ==================================================
# ITER. # 144: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.65770222e+00 -1.01443048e-04 -9.50899371e-05]
# ==================================================
# ITER. # 145: Size of P: 500| Best Fitness: 5.27402e+09 | Best Hypothesis: [-1.35436346e+00 -9.55835967e-05 -2.36714732e-05]
# ==================================================
# ITER. # 146: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.82954454e+00 -4.13463662e-04 -5.15353880e-04]
# ==================================================
# ITER. # 147: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.80429278e+00 -3.64753289e-04 -3.31087036e-04]
# ==================================================
# ITER. # 148: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.32815541e+00 -3.88681856e-04 -1.96551355e-04]
# ==================================================
# ITER. # 149: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.31523866e+00 -3.60542868e-04 -7.43807080e-04]
# ==================================================
# ITER. # 150: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.05005672e+00 -3.49603198e-04 -3.25954529e-04]
# ==================================================
# ITER. # 151: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.28846007e+00 -3.28199517e-04 -3.50218840e-04]
# ==================================================
# ITER. # 152: Size of P: 500| Best Fitness: 5.27403e+09 | Best Hypothesis: [-1.34915267e+00 -1.47645121e-04 -1.15801981e-03]
# ==================================================
# ITER. # 153: Size of P: 500| Best Fitness: 5.27393e+09 | Best Hypothesis: [-2.37723658e+00 -1.01006908e-04 -2.10378268e-04]
# ==================================================
# ITER. # 154: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-1.88917591e+00 -5.76356622e-04 -7.86541426e-05]
# ==================================================
# ITER. # 155: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-1.64752817e+00 -4.05658944e-04 -1.81938809e-03]
# ==================================================
# ITER. # 156: Size of P: 500| Best Fitness: 5.27414e+09 | Best Hypothesis: [-7.02659461e-01 -1.34927153e-04 -4.97136191e-03]
# ==================================================
# ITER. # 157: Size of P: 500| Best Fitness: 5.27403e+09 | Best Hypothesis: [-1.65476474e+00 -6.12631211e-04 -5.36449481e-04]
# ==================================================
# ITER. # 158: Size of P: 500| Best Fitness: 5.27404e+09 | Best Hypothesis: [-2.75744180e+00 -9.71679614e-04 -8.26136144e-05]
# ==================================================
# ITER. # 159: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-1.61012304e+00 -3.17264747e-05 -2.81363426e-04]
# ==================================================
# ITER. # 160: Size of P: 500| Best Fitness: 5.27405e+09 | Best Hypothesis: [-1.37466233e+00 -4.44279885e-04 -1.29611380e-03]
# ==================================================
# ITER. # 161: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-1.73284205e+00 -1.33405450e-04 -4.86846821e-04]
# ==================================================
# ITER. # 162: Size of P: 500| Best Fitness: 5.27403e+09 | Best Hypothesis: [-1.30577787e+00 -8.91455825e-05 -8.83442881e-05]
# ==================================================
# ITER. # 163: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.30915183e+00 -1.32926953e-04 -7.35076960e-04]
# ==================================================
# ITER. # 164: Size of P: 500| Best Fitness: 5.27402e+09 | Best Hypothesis: [-1.47227869e+00 -2.43989345e-04 -1.97997156e-04]
# ==================================================
# ITER. # 165: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.84785133e+00 -3.23627732e-04 -2.03146922e-03]
# ==================================================
# ITER. # 166: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.41333824e+00 -1.38319215e-04 -3.49431834e-05]
# ==================================================
# ITER. # 167: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-3.15155911e+00 -2.54587741e-04 -9.42727903e-05]
# ==================================================
# ITER. # 168: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-1.88918458e+00 -7.35089566e-04 -2.93795074e-05]
# ==================================================
# ITER. # 169: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.69485031e+00 -1.89871132e-04 -3.84019421e-04]
# ==================================================
# ITER. # 170: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.15443998e+00 -2.70123750e-04 -6.15015586e-04]
# ==================================================
# ITER. # 171: Size of P: 500| Best Fitness: 5.27425e+09 | Best Hypothesis: [-6.33784666e-01 -5.72224581e-04 -3.55546754e-04]
# ==================================================
# ITER. # 172: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.70659601e+00 -3.49772460e-05 -1.03849166e-04]
# ==================================================
# ITER. # 173: Size of P: 500| Best Fitness: 5.27407e+09 | Best Hypothesis: [-2.42486530e+00 -2.90841920e-04 -5.82112392e-03]
# ==================================================
# ITER. # 174: Size of P: 500| Best Fitness: 5.27408e+09 | Best Hypothesis: [-1.00956160e+00 -1.31498611e-04 -2.52482908e-03]
# ==================================================
# ITER. # 175: Size of P: 500| Best Fitness: 5.27403e+09 | Best Hypothesis: [-2.10117880e+00 -9.71339079e-04 -2.08222960e-04]
# ==================================================
# ITER. # 176: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-2.06434110e+00 -4.05054274e-04 -1.68340070e-03]
# ==================================================
# ITER. # 177: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-2.11883012e+00 -3.82337822e-04 -1.28061741e-03]
# ==================================================
# ITER. # 178: Size of P: 500| Best Fitness: 5.27425e+09 | Best Hypothesis: [-0.71188005 -0.0012639  -0.00598754]
# ==================================================
# ITER. # 179: Size of P: 500| Best Fitness: 5.27427e+09 | Best Hypothesis: [-0.00013133 -0.00019358 -0.01542273]
# ==================================================
# ITER. # 180: Size of P: 500| Best Fitness: 5.27427e+09 | Best Hypothesis: [-0.01595243 -0.00012564 -0.01038554]
# ==================================================
# ITER. # 181: Size of P: 500| Best Fitness: 5.27427e+09 | Best Hypothesis: [-0.000405   -0.00018729 -0.01574798]
# ==================================================
# ITER. # 182: Size of P: 500| Best Fitness: 5.27429e+09 | Best Hypothesis: [-0.00061993 -0.000387   -0.01233655]
# ==================================================
# ITER. # 183: Size of P: 500| Best Fitness: 5.27405e+09 | Best Hypothesis: [-2.58391242e+00 -5.30374086e-04 -3.32977658e-03]
# ==================================================
# ITER. # 184: Size of P: 500| Best Fitness: 5.27408e+09 | Best Hypothesis: [-1.12557627e+00 -2.74398619e-04 -9.87022089e-04]
# ==================================================
# ITER. # 185: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-1.93218149e+00 -4.35656785e-04 -4.31554534e-04]
# ==================================================
# ITER. # 186: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-2.41424747e+00 -5.17705887e-04 -1.44449299e-04]
# ==================================================
# ITER. # 187: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-1.50718589e+00 -1.51892859e-04 -3.35424812e-03]
# ==================================================
# ITER. # 188: Size of P: 500| Best Fitness: 5.27419e+09 | Best Hypothesis: [-8.72811825e-01 -7.13671753e-04 -5.41581297e-04]
# ==================================================
# ITER. # 189: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.39174653e+00 -3.14267836e-04 -6.63477502e-04]
# ==================================================
# ITER. # 190: Size of P: 500| Best Fitness: 5.27426e+09 | Best Hypothesis: [-0.00173617 -0.00011349 -0.01281794]
# ==================================================
# ITER. # 191: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-1.89369057e+00 -2.40885132e-04 -1.57085159e-04]
# ==================================================
# ITER. # 192: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-2.65965297e+00 -8.66132786e-05 -3.42287259e-04]
# ==================================================
# ITER. # 193: Size of P: 500| Best Fitness: 5.27393e+09 | Best Hypothesis: [-2.43484831e+00 -1.07887303e-04 -1.83178666e-04]
# ==================================================
# ITER. # 194: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.26871134e+00 -2.06739188e-04 -1.15201811e-04]
# ==================================================
# ITER. # 195: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-2.39981285e+00 -2.05798343e-04 -5.99212904e-04]
# ==================================================
# ITER. # 196: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.22123783e+00 -2.81956759e-04 -5.71335354e-04]
# ==================================================
# ITER. # 197: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-1.87794020e+00 -3.50297992e-04 -9.84469952e-04]
# ==================================================
# ITER. # 198: Size of P: 500| Best Fitness: 5.27393e+09 | Best Hypothesis: [-2.48931303e+00 -3.85358772e-05 -1.58631163e-04]
# ==================================================
# ITER. # 199: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-1.94982329e+00 -6.95677641e-05 -6.07072808e-04]
# ==================================================
# ITER. # 200: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-1.47825063e+00 -9.55704567e-05 -3.00194734e-03]
# ==================================================
# ITER. # 201: Size of P: 500| Best Fitness: 5.27406e+09 | Best Hypothesis: [-1.74476530e+00 -4.70922004e-04 -6.25013744e-03]
# ==================================================
# ITER. # 202: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.28293805e+00 -6.58060269e-05 -8.24768705e-04]
# ==================================================
# ITER. # 203: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.17281960e+00 -3.05718302e-04 -1.14169226e-04]
# ==================================================
# ITER. # 204: Size of P: 500| Best Fitness: 5.27393e+09 | Best Hypothesis: [-2.17067919e+00 -2.98520094e-05 -2.16396292e-04]
# ==================================================
# ITER. # 205: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.70915333e+00 -1.06424588e-04 -8.77728124e-04]
# ==================================================
# ITER. # 206: Size of P: 500| Best Fitness: 5.27402e+09 | Best Hypothesis: [-1.67240720e+00 -4.92476935e-04 -1.25966195e-03]
# ==================================================
# ITER. # 207: Size of P: 500| Best Fitness: 5.27412e+09 | Best Hypothesis: [-1.45564012e+00 -1.21485576e-03 -1.70901089e-03]
# ==================================================
# ITER. # 208: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-2.97520892e+00 -2.01603306e-04 -4.07232849e-04]
# ==================================================
# ITER. # 209: Size of P: 500| Best Fitness: 5.27407e+09 | Best Hypothesis: [-1.38912024e+00 -5.95429615e-04 -2.23009636e-04]
# ==================================================
# ITER. # 210: Size of P: 500| Best Fitness: 5.27419e+09 | Best Hypothesis: [-6.16849625e-01 -3.37498290e-04 -1.37833082e-02]
# ==================================================
# ITER. # 211: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-2.62947944e+00 -1.39188779e-04 -2.09102105e-04]
# ==================================================
# ITER. # 212: Size of P: 500| Best Fitness: 5.27411e+09 | Best Hypothesis: [-9.22873107e-01 -5.47803770e-05 -9.20712424e-05]
# ==================================================
# ITER. # 213: Size of P: 500| Best Fitness: 5.27410e+09 | Best Hypothesis: [-3.15921325e+00 -6.19809422e-04 -1.73870574e-03]
# ==================================================
# ITER. # 214: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-2.14204612e+00 -5.71120922e-04 -1.74547582e-03]
# ==================================================
# ITER. # 215: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-1.79173347e+00 -5.68422146e-04 -3.42588416e-04]
# ==================================================
# ITER. # 216: Size of P: 500| Best Fitness: 5.27407e+09 | Best Hypothesis: [-1.27767011e+00 -4.17634454e-04 -1.44407178e-04]
# ==================================================
# ITER. # 217: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-2.60777969e+00 -2.23975403e-04 -2.21608364e-03]
# ==================================================
# ITER. # 218: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.50963492e+00 -1.61955609e-04 -1.88065690e-03]
# ==================================================
# ITER. # 219: Size of P: 500| Best Fitness: 5.27404e+09 | Best Hypothesis: [-1.23864446e+00 -1.02582203e-04 -1.47572177e-03]
# ==================================================
# ITER. # 220: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.03102762e+00 -1.62524226e-04 -2.60142942e-03]
# ==================================================
# ITER. # 221: Size of P: 500| Best Fitness: 5.27412e+09 | Best Hypothesis: [-8.21333607e-01 -9.10362364e-05 -3.38923463e-03]
# ==================================================
# ITER. # 222: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.73259270e+00 -3.69023720e-04 -6.56923888e-05]
# ==================================================
# ITER. # 223: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-1.87758583e+00 -3.59509426e-04 -3.87729795e-05]
# ==================================================
# ITER. # 224: Size of P: 500| Best Fitness: 5.27413e+09 | Best Hypothesis: [-2.07112009e+00 -1.93607640e-03 -7.40720997e-04]
# ==================================================
# ITER. # 225: Size of P: 500| Best Fitness: 5.27424e+09 | Best Hypothesis: [-2.46898246e+00 -2.98765249e-03 -8.01136142e-04]
# ==================================================
# ITER. # 226: Size of P: 500| Best Fitness: 5.27406e+09 | Best Hypothesis: [-1.45769261e+00 -6.83529063e-04 -1.70235008e-03]
# ==================================================
# ITER. # 227: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-1.86602254e+00 -5.98841341e-04 -3.85121781e-04]
# ==================================================
# ITER. # 228: Size of P: 500| Best Fitness: 5.27422e+09 | Best Hypothesis: [-6.10397715e-01 -1.65194841e-04 -5.53538506e-05]
# ==================================================
# ITER. # 229: Size of P: 500| Best Fitness: 5.27415e+09 | Best Hypothesis: [-1.47574477e+00 -1.54572555e-03 -1.55096316e-04]
# ==================================================
# ITER. # 230: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.23884716e+00 -5.11841447e-04 -1.05726158e-04]
# ==================================================
# ITER. # 231: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-2.67985502e+00 -7.14253178e-05 -2.44790835e-03]
# ==================================================
# ITER. # 232: Size of P: 500| Best Fitness: 5.27406e+09 | Best Hypothesis: [-1.15348169e+00 -8.10417609e-05 -1.06281141e-03]
# ==================================================
# ITER. # 233: Size of P: 500| Best Fitness: 5.27412e+09 | Best Hypothesis: [-1.25724131e+00 -8.85126938e-04 -1.85782862e-03]
# ==================================================
# ITER. # 234: Size of P: 500| Best Fitness: 5.27408e+09 | Best Hypothesis: [-2.20302543e+00 -1.35869554e-03 -1.31757559e-03]
# ==================================================
# ITER. # 235: Size of P: 500| Best Fitness: 5.27402e+09 | Best Hypothesis: [-1.95632498e+00 -8.51253016e-04 -3.52402317e-04]
# ==================================================
# ITER. # 236: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.43276750e+00 -3.74874778e-04 -3.51094406e-04]
# ==================================================
# ITER. # 237: Size of P: 500| Best Fitness: 5.27409e+09 | Best Hypothesis: [-1.07464681e+00 -3.34466124e-04 -2.00797299e-03]
# ==================================================
# ITER. # 238: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.80443743e+00 -4.05296926e-04 -2.65042330e-04]
# ==================================================
# ITER. # 239: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-1.76402094e+00 -6.02462213e-04 -1.78217688e-04]
# ==================================================
# ITER. # 240: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-1.54127792e+00 -1.50459887e-04 -1.18340561e-04]
# ==================================================
# ITER. # 241: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-1.92196002e+00 -6.87041678e-04 -3.44277702e-05]
# ==================================================
# ITER. # 242: Size of P: 500| Best Fitness: 5.27424e+09 | Best Hypothesis: [-1.79790802e+00 -2.79086425e-03 -8.93392965e-04]
# ==================================================
# ITER. # 243: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.43034151e+00 -1.99051000e-04 -1.11946008e-04]
# ==================================================
# ITER. # 244: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.59742437e+00 -1.36967428e-04 -1.81275231e-04]
# ==================================================
# ITER. # 245: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.02509980e+00 -2.33203488e-04 -1.79053110e-03]
# ==================================================
# ITER. # 246: Size of P: 500| Best Fitness: 5.27410e+09 | Best Hypothesis: [-1.27027308e+00 -7.58616856e-04 -4.80507076e-04]
# ==================================================
# ITER. # 247: Size of P: 500| Best Fitness: 5.27408e+09 | Best Hypothesis: [-1.66924815e+00 -7.80174505e-05 -9.80685838e-03]
# ==================================================
# ITER. # 248: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-1.89806236e+00 -1.77821965e-04 -3.69688098e-04]
# ==================================================
# ITER. # 249: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-2.19454872e+00 -5.49022292e-04 -2.50716209e-03]
# ==================================================
# ITER. # 250: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-2.20420172e+00 -1.24093326e-04 -1.03678079e-03]
# ==================================================
# ITER. # 251: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.24724402e+00 -1.37820425e-04 -4.73174242e-05]
# ==================================================
# ITER. # 252: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-1.92245759e+00 -9.05570330e-05 -5.93443907e-04]
# ==================================================
# ITER. # 253: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-1.47387486e+00 -2.76111681e-05 -2.92700927e-03]
# ==================================================
# ITER. # 254: Size of P: 500| Best Fitness: 5.27413e+09 | Best Hypothesis: [-1.04125093e+00 -4.87090515e-04 -2.14282214e-04]
# ==================================================
# ITER. # 255: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-3.20445961e+00 -2.00954463e-05 -4.27043485e-04]
# ==================================================
# ITER. # 256: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-2.78779037e+00 -4.02898544e-04 -1.53272764e-04]
# ==================================================
# ITER. # 257: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-1.86356050e+00 -1.84684734e-04 -2.28424763e-03]
# ==================================================
# ITER. # 258: Size of P: 500| Best Fitness: 5.27393e+09 | Best Hypothesis: [-2.16797780e+00 -5.79184405e-05 -1.96234051e-04]
# ==================================================
# ITER. # 259: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.21391348e+00 -1.15272392e-04 -5.24356392e-04]
# ==================================================
# ITER. # 260: Size of P: 500| Best Fitness: 5.27422e+09 | Best Hypothesis: [-5.85705720e-01 -2.03215154e-04 -6.52259540e-04]
# ==================================================
# ITER. # 261: Size of P: 500| Best Fitness: 5.27425e+09 | Best Hypothesis: [-3.36798430e-02 -8.61017623e-05 -1.45567986e-02]
# ==================================================
# ITER. # 262: Size of P: 500| Best Fitness: 5.27405e+09 | Best Hypothesis: [-3.32697332e+00 -3.12601047e-04 -3.42702104e-05]
# ==================================================
# ITER. # 263: Size of P: 500| Best Fitness: 5.27403e+09 | Best Hypothesis: [-1.43729802e+00 -3.07509865e-04 -6.86250695e-04]
# ==================================================
# ITER. # 264: Size of P: 500| Best Fitness: 5.27393e+09 | Best Hypothesis: [-2.37569752e+00 -4.07389326e-05 -5.00890694e-04]
# ==================================================
# ITER. # 265: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-2.59219724e+00 -2.37631915e-04 -1.79285324e-04]
# ==================================================
# ITER. # 266: Size of P: 500| Best Fitness: 5.27405e+09 | Best Hypothesis: [-1.17478101e+00 -1.51221991e-05 -7.27967174e-04]
# ==================================================
# ITER. # 267: Size of P: 500| Best Fitness: 5.27421e+09 | Best Hypothesis: [-3.03854501e-01 -1.39329013e-04 -1.00359476e-02]
# ==================================================
# ITER. # 268: Size of P: 500| Best Fitness: 5.27426e+09 | Best Hypothesis: [-1.03121397e-04 -8.24118103e-05 -1.59772977e-02]
# ==================================================
# ITER. # 269: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.46578236e+00 -5.05372521e-04 -8.41467242e-05]
# ==================================================
# ITER. # 270: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.82136763e+00 -1.60433428e-04 -5.77063473e-04]
# ==================================================
# ITER. # 271: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.08644731e+00 -9.80192940e-05 -2.07634921e-04]
# ==================================================
# ITER. # 272: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.38486989e+00 -4.00735291e-04 -5.15086743e-04]
# ==================================================
# ITER. # 273: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-2.34709612e+00 -2.01840713e-04 -3.78085055e-04]
# ==================================================
# ITER. # 274: Size of P: 500| Best Fitness: 5.27406e+09 | Best Hypothesis: [-1.14644569e+00 -1.05022753e-04 -1.88249549e-04]
# ==================================================
# ITER. # 275: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.49761005e+00 -4.32120357e-04 -9.78447053e-05]
# ==================================================
# ...
# ==================================================
# ITER. # 553: Size of P: 500| Best Fitness: 5.27410e+09 | Best Hypothesis: [-1.10675599e+00 -3.41467835e-04 -2.70058911e-04]
# ==================================================
# ITER. # 554: Size of P: 500| Best Fitness: 5.27416e+09 | Best Hypothesis: [-1.00224701e+00 -7.53934587e-04 -1.19243072e-04]
# ==================================================
# ITER. # 555: Size of P: 500| Best Fitness: 5.27410e+09 | Best Hypothesis: [-1.31234500e+00 -8.06688731e-04 -1.41423143e-04]
# ==================================================
# ITER. # 556: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-2.40413189e+00 -6.45931537e-04 -1.83977536e-04]
# ==================================================
# ITER. # 557: Size of P: 500| Best Fitness: 5.27405e+09 | Best Hypothesis: [-3.08353455e+00 -7.24546941e-04 -9.83340588e-05]
# ==================================================
# ITER. # 558: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.55805439e+00 -1.32382663e-04 -1.62774541e-03]
# ==================================================
# ITER. # 559: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-1.46199937e+00 -8.38602580e-05 -1.45756274e-03]
# ==================================================
# ITER. # 560: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-1.75090109e+00 -4.50532126e-04 -6.54079156e-04]
# ==================================================
# ITER. # 561: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-2.43507610e+00 -5.77412565e-04 -6.20306975e-04]
# ==================================================
# ITER. # 562: Size of P: 500| Best Fitness: 5.27404e+09 | Best Hypothesis: [-1.62787610e+00 -6.21434173e-05 -7.73782351e-03]
# ==================================================
# ITER. # 563: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-1.95029084e+00 -1.29759592e-04 -4.11933736e-04]
# ==================================================
# ITER. # 564: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-1.75457872e+00 -4.53041984e-05 -3.76789012e-04]
# ==================================================
# ITER. # 565: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.04060275e+00 -7.22219570e-05 -3.60997509e-04]
# ==================================================
# ITER. # 566: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-1.69101034e+00 -5.16195127e-05 -1.99681320e-04]
# ==================================================
# ITER. # 567: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-2.73149898e+00 -5.67620754e-04 -4.03954023e-04]
# ==================================================
# ITER. # 568: Size of P: 500| Best Fitness: 5.27402e+09 | Best Hypothesis: [-2.20714740e+00 -6.73344779e-04 -2.36128763e-03]
# ==================================================
# ITER. # 569: Size of P: 500| Best Fitness: 5.27403e+09 | Best Hypothesis: [-2.62670546e+00 -5.40673388e-04 -2.21101577e-03]
# ==================================================
# ITER. # 570: Size of P: 500| Best Fitness: 5.27406e+09 | Best Hypothesis: [-1.22962306e+00 -2.76539218e-04 -1.06332087e-03]
# ==================================================
# ITER. # 571: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-2.29674172e+00 -7.50078936e-04 -9.86687642e-04]
# ==================================================
# ITER. # 572: Size of P: 500| Best Fitness: 5.27402e+09 | Best Hypothesis: [-1.96944530e+00 -7.51808296e-04 -1.12851521e-03]
# ==================================================
# ITER. # 573: Size of P: 500| Best Fitness: 5.27418e+09 | Best Hypothesis: [-6.80056589e-01 -1.05906687e-04 -3.99302747e-04]
# ==================================================
# ITER. # 574: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-1.90626696e+00 -1.04398831e-04 -1.17513760e-04]
# ==================================================
# ITER. # 575: Size of P: 500| Best Fitness: 5.27417e+09 | Best Hypothesis: [-3.66373153e+00 -6.27753261e-04 -4.08020478e-04]
# ==================================================
# ITER. # 576: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.02244799e+00 -4.03708507e-04 -2.08650460e-04]
# ==================================================
# ITER. # 577: Size of P: 500| Best Fitness: 5.27415e+09 | Best Hypothesis: [-8.51763727e-01 -2.51270241e-04 -2.49311875e-04]
# ==================================================
# ITER. # 578: Size of P: 500| Best Fitness: 5.27427e+09 | Best Hypothesis: [-6.18431171e-05 -5.00082059e-05 -1.81647407e-02]
# ==================================================
# ITER. # 579: Size of P: 500| Best Fitness: 5.27408e+09 | Best Hypothesis: [-1.68429746e+00 -1.19875499e-03 -3.51081636e-04]
# ==================================================
# ITER. # 580: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-2.75543978e+00 -3.20028504e-04 -7.10340247e-04]
# ==================================================
# ITER. # 581: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-1.83129847e+00 -1.28996650e-04 -4.07251343e-04]
# ==================================================
# ITER. # 582: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-2.27860093e+00 -1.67280642e-04 -3.26572868e-03]
# ==================================================
# ITER. # 583: Size of P: 500| Best Fitness: 5.27405e+09 | Best Hypothesis: [-1.24513000e+00 -2.06632630e-04 -1.26075412e-04]
# ==================================================
# ITER. # 584: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-1.84580490e+00 -7.98867556e-05 -2.04501065e-03]
# ==================================================
# ITER. # 585: Size of P: 500| Best Fitness: 5.27416e+09 | Best Hypothesis: [-7.49267277e-01 -1.53281304e-04 -1.00043118e-03]
# ==================================================
# ITER. # 586: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.39614100e+00 -4.51241932e-04 -5.59021734e-04]
# ==================================================
# ITER. # 587: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-2.29480272e+00 -5.46337473e-04 -7.10095538e-04]
# ==================================================
# ITER. # 588: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-1.98211988e+00 -5.71988955e-05 -3.82078290e-03]
# ==================================================
# ITER. # 589: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-2.27424878e+00 -4.18844820e-04 -9.34165626e-04]
# ==================================================
# ITER. # 590: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-2.83262825e+00 -1.12342656e-04 -9.79361693e-04]
# ==================================================
# ITER. # 591: Size of P: 500| Best Fitness: 5.27410e+09 | Best Hypothesis: [-2.82695537e+00 -8.70050847e-04 -2.86838781e-03]
# ==================================================
# ITER. # 592: Size of P: 500| Best Fitness: 5.27406e+09 | Best Hypothesis: [-1.80634710e+00 -1.05685095e-03 -3.74077510e-04]
# ==================================================
# ITER. # 593: Size of P: 500| Best Fitness: 5.27405e+09 | Best Hypothesis: [-1.67117152e+00 -7.76929577e-04 -2.01207048e-03]
# ==================================================
# ITER. # 594: Size of P: 500| Best Fitness: 5.27403e+09 | Best Hypothesis: [-1.86794296e+00 -8.81244134e-04 -3.43166801e-04]
# ==================================================
# ITER. # 595: Size of P: 500| Best Fitness: 5.27408e+09 | Best Hypothesis: [-1.07136381e+00 -1.04439774e-04 -1.60246766e-04]
# ==================================================
# ITER. # 596: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-1.88805362e+00 -3.32680091e-04 -3.16243529e-05]
# ==================================================
# ITER. # 597: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.20050248e+00 -2.01240168e-04 -1.88782685e-04]
# ==================================================
# ITER. # 598: Size of P: 500| Best Fitness: 5.27411e+09 | Best Hypothesis: [-9.93465726e-01 -2.35359818e-04 -8.59589720e-05]
# ==================================================
# ITER. # 599: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-2.82167733e+00 -2.76584860e-04 -6.11700987e-04]
# ==================================================
# ITER. # 600: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-1.75627801e+00 -1.38134895e-04 -2.41632787e-03]
# ==================================================
# ITER. # 601: Size of P: 500| Best Fitness: 5.27400e+09 | Best Hypothesis: [-3.03727542e+00 -4.26591826e-05 -9.58753992e-04]
# ==================================================
# ITER. # 602: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-1.71098980e+00 -5.58754177e-04 -1.86373069e-04]
# ==================================================
# ITER. # 603: Size of P: 500| Best Fitness: 5.27393e+09 | Best Hypothesis: [-2.21482407e+00 -4.76231437e-05 -3.33486228e-05]
# ==================================================
# ITER. # 604: Size of P: 500| Best Fitness: 5.27403e+09 | Best Hypothesis: [-1.42663634e+00 -2.59572276e-04 -2.98493538e-03]
# ==================================================
# ITER. # 605: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-1.54777400e+00 -3.14053521e-04 -2.05254251e-04]
# ==================================================
# ITER. # 606: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.03894227e+00 -2.55280298e-04 -2.36529074e-04]
# ==================================================
# ITER. # 607: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-1.98910425e+00 -3.44988060e-04 -2.10375891e-04]
# ==================================================
# ITER. # 608: Size of P: 500| Best Fitness: 5.27399e+09 | Best Hypothesis: [-1.50480269e+00 -5.70136801e-05 -3.46069693e-04]
# ==================================================
# ITER. # 609: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-2.07014985e+00 -2.41947509e-04 -2.15719592e-04]
# ==================================================
# ITER. # 610: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-2.63489981e+00 -1.45676703e-04 -8.10395817e-04]
# ==================================================
# ITER. # 611: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-1.70167279e+00 -1.17917834e-04 -3.46140684e-04]
# ==================================================
# ITER. # 612: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-3.00871316e+00 -1.27005058e-04 -1.61001237e-04]
# ==================================================
# ITER. # 613: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-1.89712672e+00 -6.52146514e-05 -8.22114433e-05]
# ==================================================
# ITER. # 614: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.05168473e+00 -4.65788619e-05 -2.97269186e-03]
# ==================================================
# ITER. # 615: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.47356984e+00 -1.66535579e-05 -2.82562088e-03]
# ==================================================
# ITER. # 616: Size of P: 500| Best Fitness: 5.27394e+09 | Best Hypothesis: [-2.64314272e+00 -1.95848545e-05 -2.54971739e-04]
# ==================================================
# ITER. # 617: Size of P: 500| Best Fitness: 5.27393e+09 | Best Hypothesis: [-2.04410893e+00 -2.25661447e-05 -4.67390941e-04]
# ==================================================
# ITER. # 618: Size of P: 500| Best Fitness: 5.27398e+09 | Best Hypothesis: [-1.62994492e+00 -7.69858467e-05 -5.30640537e-05]
# ==================================================
# ITER. # 619: Size of P: 500| Best Fitness: 5.27395e+09 | Best Hypothesis: [-1.81730757e+00 -6.80531579e-05 -5.91867316e-05]
# ==================================================
# ITER. # 620: Size of P: 500| Best Fitness: 5.27412e+09 | Best Hypothesis: [-8.93342017e-01 -3.35086152e-05 -3.62985743e-05]
# ==================================================
# ITER. # 621: Size of P: 500| Best Fitness: 5.27425e+09 | Best Hypothesis: [-1.14718890e-03 -1.73218116e-05 -1.50365865e-02]
# ==================================================
# ITER. # 622: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-2.22564226e+00 -2.26761827e-04 -1.74352772e-03]
# ==================================================
# ITER. # 623: Size of P: 500| Best Fitness: 5.27396e+09 | Best Hypothesis: [-1.76451285e+00 -1.16775444e-04 -1.23359114e-04]
# ==================================================
# ITER. # 624: Size of P: 500| Best Fitness: 5.27393e+09 | Best Hypothesis: [-2.28135034e+00 -2.53351267e-05 -4.34597637e-04]
# ==================================================
# ITER. # 625: Size of P: 500| Best Fitness: 5.27406e+09 | Best Hypothesis: [-1.13365474e+00 -1.41424134e-05 -2.22163809e-04]
# ==================================================
# ITER. # 626: Size of P: 500| Best Fitness: 5.27408e+09 | Best Hypothesis: [-1.60858911e+00 -1.02656990e-03 -7.72273560e-04]
# ==================================================
# ITER. # 627: Size of P: 500| Best Fitness: 5.27401e+09 | Best Hypothesis: [-2.71979508e+00 -7.31661421e-04 -2.28351354e-04]
# ==================================================
# ITER. # 628: Size of P: 500| Best Fitness: 5.27407e+09 | Best Hypothesis: [-1.21037887e+00 -3.01172622e-04 -1.34396638e-04]
# ==================================================
# ITER. # 629: Size of P: 500| Best Fitness: 5.27405e+09 | Best Hypothesis: [-1.75052047e+00 -8.65059865e-04 -2.34996140e-03]
# ==================================================
# ITER. # 630: Size of P: 500| Best Fitness: 5.27397e+09 | Best Hypothesis: [-1.75602072e+00 -1.98518508e-04 -3.88682469e-04]
# ==================================================
# ITER. # 631: Size of P: 500| Best Fitness: 5.27416e+09 | Best Hypothesis: [-7.69082166e-01 -1.01958144e-04 -2.17842778e-04]
# ==================================================
# ITER. # 632: Size of P: 500| Best Fitness: 5.27403e+09 | Best Hypothesis: [-2.44473272e+00 -9.85527825e-04 -4.67009254e-04]
# ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 GA.run()
#
# Cell In[3], line 209, in GeneticAlgorithm.run(self)
#     202             continue_cond = lambda : self.best_fitness < self.fitness_threshold
#     204         while continue_cond() and iterations < 1000:
#     205
#     206 #             print(self.P.shape)
#     207
#     208             # 1) Select
# --> 209             Ps = self.select()
#     210 #             print(self.P.shape, Ps.shape)
#     211
#     212             # 2) Crossover
#     213             offspring = np.array(self.CrossoverOperator())
#
# Cell In[3], line 167, in GeneticAlgorithm.select(self)
#     164 def select(self):
#     166     P = self.P
# --> 167     Pr_P = [self.Pr(h) for h in P]
#     169     p = P.shape[0]
#     170     r = self.r
#
# Cell In[3], line 167, in <listcomp>(.0)
#     164 def select(self):
#     166     P = self.P
# --> 167     Pr_P = [self.Pr(h) for h in P]
#     169     p = P.shape[0]
#     170     r = self.r
#
# Cell In[3], line 162, in GeneticAlgorithm.Pr(self, h)
#     160 def Pr(self, h):
# --> 162     return self.fitness(h) / sum(self.fitness(h_j) for h_j in self.P)
#
# Cell In[3], line 162, in <genexpr>(.0)
#     160 def Pr(self, h):
# --> 162     return self.fitness(h) / sum(self.fitness(h_j) for h_j in self.P)
#
# Cell In[6], line 16, in fitness(w)
#      13 y_predicted = f(x, w)
#      14 r = (y - y_predicted)**2
# ---> 16 return r.sum()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\_methods.py:48, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# KeyboardInterrupt:
